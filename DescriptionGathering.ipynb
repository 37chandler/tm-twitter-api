# %% [markdown]
# ## Gather Follower Descriptions
# We start with a twitter user name (as well as things like twitter credentials) and pull all the followers of that user. We then pull the descriptions of those users and write them to a file for future mining. You can use more than one user in a group.
#
# I wrote some functions for you in the file `twitter_functions.py`. This will need to be in the same folder where you're running this notebook.
#
# You may not have installed `tweepy` yet. If you get an error on the next cell, you need to go to the command/console line (like where you type `git` commands) and type something like `pip install tweepy`. There may be dependencies (like `unidecode`) that you need as well.

# %%
from datetime import datetime
import json
from pprint import pprint

from twitter_functions import * # these are the functions I wrote for you.

# %% [markdown]
# The next cell holds your Twitter authorization credentials. Then it calls a function that initializes your connection to Twitter. I've left my keys in there (slightly perturbed so that they won't actually work) so that you see the form these take).

# %%
from twitter_config import *

#auth =  { "consumer_key": "xks2XTK4gr2PajPio1RBGWsYU",
#          "consumer_secret": "jkjkCjph2vx38uBVbVHLkhzesGVY6ZqEywXd3B0sDeSAWVcDNo",
#          "access_key": "33029025-i1Mm907o7BsKnufMIxjVzByKsuDEhOBb0yV3EAa1E",
#          "access_secret": "jkjkXqAijIwRQMZmW3b7AgpFXU6Ve0RU30fzsbzpfx9uf"
#        }

api = initialize_twitter(auth)

# %% [markdown]
# Now you set the handle (or handles) that represent one group or topic on Twitter. These should be in a list. The output file name (`ofile_name`) is determined based on today's date and the first element in the list. Feel free to modify.

# %%
starting_user = ['GeneralMills','KraftBrand'] # my first group
#starting_user = ['michaelpollan'] # my second group

ofile_name = (datetime.today().strftime("%Y%m%d") + "_" + 
             starting_user[0] + "_" + # Just use the first starting_user for the name if there are multiple
             "followers.txt")

# %%
# We'll now go lookup the full information on your starting user(s). 
starting_user_id = []

# All records will be a dictionary with the twitter ID as the key and 
# a UserRecord as the value. This is a named tuple I created. 
all_records = lookup_users_from_handles(api, starting_user)

# We need the IDs that we're getting followers from in a list. 
for id in all_records : #access the keys, which are ids.
    starting_user_id.append(id)
# Out:
# Start lookup_users_from_ids on 2 handles.
# 20191014-153408: looking up user records for 2 handles.
# 20191014-153408:  users pulled:  2
# total failures: 0

# %%
all_records
# Out:
# defaultdict(twitter_functions.UserRecord,
#             {280557152: UserRecord(id=280557152, id_str='280557152', name='General Mills', screen_name='GeneralMills', location='Minneapolis', followers_count=96999, friends_count=3437, favourites_count=7839, description='News/information from General Mills. Learn more at https://t.co/K7ale2Yhbq and https://t.co/brNL7A0kV1', geo_enabled=False, lang=None, statuses_count=18693, time_zone=None, created_at='Mon Apr 11 15:26:07 +0000 2011', verified=True, utc_offset=None, contributors_enabled=False, listed_count=911, protected=False, url='https://t.co/brNL7A0kV1'),
#              908425516914528257: UserRecord(id=908425516914528257, id_str='908425516914528257', name='Kraft', screen_name='KraftBrand', location='', followers_count=3616, friends_count=163, favourites_count=1127, description='We make delicious food for families. #ForTheWinWin', geo_enabled=False, lang=None, statuses_count=3227, time_zone=None, created_at='Thu Sep 14 20:21:35 +0000 2017', verified=True, utc_offset=None, contributors_enabled=False, listed_count=52, protected=False, url='https://t.co/lUX0geGSrA')})

# %%
# How long is it going to take us to pull these followers?
total_followers = 0
for id, rec in all_records.items() :
    total_followers += rec.followers_count
    
print("Ooh, {fol:,d} followers. A complete run with no limits run is ".format(fol=total_followers) + 
      "going to take {min:.2f} minutes ({hour:.2f} hours)".format(min=total_followers/5000,
                                                                  hour=total_followers/(60*5000)))
# Out:
# Ooh, 100,615 followers. A complete run with no limits run is going to take 20.12 minutes (0.34 hours)

# %%
# Now let's pull all the followers of our starting_user
# the function I wrote allows you to cap the number of followers you pull
# and uses the ID to generate the query.
# 
# Note that this pull is subject to rate limiting. You can make 15 calls per
# 15 minute window and each can return 5000 users. 
followers_of_starting = gather_followers(api,
                                         starting_user_id,
                                         follower_limit=None) # Modify this limit if you need to. 
                                                              # Set it to "None" to get all   

# followers_of_starting will be a dictionary with the key being the id(s) in starting_user_id
# and the value is a list of all the followers.
# Out:
# Pulling followers for 280557152
# Number pulled: 5000
# Number pulled: 10000
# Number pulled: 15000
# Number pulled: 20000
# Number pulled: 25000
# Number pulled: 30000
# Number pulled: 35000
# Number pulled: 40000
# Number pulled: 45000
# Number pulled: 50000
# Number pulled: 55000
# Number pulled: 60000
# Number pulled: 65000
# Number pulled: 70000
# Rate limit reached. Sleeping for: 896
# Number pulled: 75000
# Number pulled: 80000
# Number pulled: 85000
# Number pulled: 90000
# Number pulled: 95000
# Number pulled: 97000
# Pulling followers for 908425516914528257
# Number pulled: 3617

# %%
# And now we'll "hydrate" these user records.
for start_id, list_of_followers in followers_of_starting.items() :
    
    # Using a set here instead of a list so that we pull each ID only once.
    ids_to_hydrate = {id for id in list_of_followers if id not in all_records} 
    
    these_records = lookup_users_from_ids(api,ids=ids_to_hydrate)

    for id, rec in these_records.items() :
        all_records[id] = rec
# Out:
# Start lookup_users_from_ids on 97000 IDs.
# 20191014-154915: looking up user records for 100 IDs.
# 20191014-154916: looking up user records for 100 IDs.
# 20191014-154917: looking up user records for 100 IDs.
# 20191014-154917: looking up user records for 100 IDs.
# 20191014-154918: looking up user records for 100 IDs.
# 20191014-154919: looking up user records for 100 IDs.
# 20191014-154920: looking up user records for 100 IDs.
# 20191014-154921: looking up user records for 100 IDs.
# 20191014-154921: looking up user records for 100 IDs.
# 20191014-154922: looking up user records for 100 IDs.
# 20191014-154923: looking up user records for 100 IDs.
# 20191014-154924: looking up user records for 100 IDs.
# 20191014-154924: looking up user records for 100 IDs.
# 20191014-154925: looking up user records for 100 IDs.
# 20191014-154926: looking up user records for 100 IDs.
# 20191014-154927: looking up user records for 100 IDs.
# 20191014-154927: looking up user records for 100 IDs.
# 20191014-154928: looking up user records for 100 IDs.
# 20191014-154929: looking up user records for 100 IDs.
# 20191014-154930: looking up user records for 100 IDs.
# 20191014-154930: looking up user records for 100 IDs.
# 20191014-154931: looking up user records for 100 IDs.
# 20191014-154932: looking up user records for 100 IDs.
# 20191014-154933: looking up user records for 100 IDs.
# 20191014-154934: looking up user records for 100 IDs.
# 20191014-154935: looking up user records for 100 IDs.
# 20191014-154935: looking up user records for 100 IDs.
# 20191014-154936: looking up user records for 100 IDs.
# 20191014-154937: looking up user records for 100 IDs.
# 20191014-154938: looking up user records for 100 IDs.
# 20191014-154938: looking up user records for 100 IDs.
# 20191014-154939: looking up user records for 100 IDs.
# 20191014-154940: looking up user records for 100 IDs.
# 20191014-154941: looking up user records for 100 IDs.
# 20191014-154941: looking up user records for 100 IDs.
# 20191014-154942: looking up user records for 100 IDs.
# 20191014-154943: looking up user records for 100 IDs.
# 20191014-154943: looking up user records for 100 IDs.
# 20191014-154944: looking up user records for 100 IDs.
# 20191014-154945: looking up user records for 100 IDs.
# 20191014-154946: looking up user records for 100 IDs.
# 20191014-154946: looking up user records for 100 IDs.
# 20191014-154947: looking up user records for 100 IDs.
# 20191014-154948: looking up user records for 100 IDs.
# 20191014-154949: looking up user records for 100 IDs.
# 20191014-154949: looking up user records for 100 IDs.
# 20191014-154950: looking up user records for 100 IDs.
# 20191014-154951: looking up user records for 100 IDs.
# 20191014-154952: looking up user records for 100 IDs.
# 20191014-154952: looking up user records for 100 IDs.
# 20191014-154953: looking up user records for 100 IDs.
# 20191014-154954: looking up user records for 100 IDs.
# 20191014-154955: looking up user records for 100 IDs.
# 20191014-154955: looking up user records for 100 IDs.
# 20191014-154956: looking up user records for 100 IDs.
# 20191014-154957: looking up user records for 100 IDs.
# 20191014-154958: looking up user records for 100 IDs.
# 20191014-154958: looking up user records for 100 IDs.
# 20191014-154959: looking up user records for 100 IDs.
# 20191014-155000: looking up user records for 100 IDs.
# 20191014-155001: looking up user records for 100 IDs.
# 20191014-155001: looking up user records for 100 IDs.
# 20191014-155002: looking up user records for 100 IDs.
# 20191014-155003: looking up user records for 100 IDs.
# 20191014-155004: looking up user records for 100 IDs.
# 20191014-155005: looking up user records for 100 IDs.
# 20191014-155005: looking up user records for 100 IDs.
# 20191014-155006: looking up user records for 100 IDs.
# 20191014-155007: looking up user records for 100 IDs.
# 20191014-155008: looking up user records for 100 IDs.
# 20191014-155009: looking up user records for 100 IDs.
# 20191014-155010: looking up user records for 100 IDs.
# 20191014-155010: looking up user records for 100 IDs.
# 20191014-155011: looking up user records for 100 IDs.
# 20191014-155012: looking up user records for 100 IDs.
# 20191014-155013: looking up user records for 100 IDs.
# 20191014-155014: looking up user records for 100 IDs.
# 20191014-155014: looking up user records for 100 IDs.
# 20191014-155015: looking up user records for 100 IDs.
# 20191014-155016: looking up user records for 100 IDs.
# 20191014-155017: looking up user records for 100 IDs.
# 20191014-155017: looking up user records for 100 IDs.
# 20191014-155018: looking up user records for 100 IDs.
# 20191014-155019: looking up user records for 100 IDs.
# 20191014-155020: looking up user records for 100 IDs.
# 20191014-155021: looking up user records for 100 IDs.
# 20191014-155021: looking up user records for 100 IDs.
# 20191014-155022: looking up user records for 100 IDs.
# 20191014-155023: looking up user records for 100 IDs.
# 20191014-155024: looking up user records for 100 IDs.
# 20191014-155024: looking up user records for 100 IDs.
# 20191014-155025: looking up user records for 100 IDs.
# 20191014-155026: looking up user records for 100 IDs.
# 20191014-155027: looking up user records for 100 IDs.
# 20191014-155027: looking up user records for 100 IDs.
# 20191014-155028: looking up user records for 100 IDs.
# 20191014-155029: looking up user records for 100 IDs.
# 20191014-155030: looking up user records for 100 IDs.
# 20191014-155030: looking up user records for 100 IDs.
# 20191014-155031: looking up user records for 100 IDs.
# 20191014-155032: looking up user records for 100 IDs.
# 20191014-155033: looking up user records for 100 IDs.
# 20191014-155033: looking up user records for 100 IDs.
# 20191014-155034: looking up user records for 100 IDs.
# 20191014-155035: looking up user records for 100 IDs.
# 20191014-155036: looking up user records for 100 IDs.
# 20191014-155036: looking up user records for 100 IDs.
# 20191014-155037: looking up user records for 100 IDs.
# 20191014-155038: looking up user records for 100 IDs.
# 20191014-155039: looking up user records for 100 IDs.
# 20191014-155039: looking up user records for 100 IDs.
# 20191014-155040: looking up user records for 100 IDs.
# 20191014-155041: looking up user records for 100 IDs.
# 20191014-155042: looking up user records for 100 IDs.
# 20191014-155042: looking up user records for 100 IDs.
# 20191014-155043: looking up user records for 100 IDs.
# 20191014-155044: looking up user records for 100 IDs.
# 20191014-155045: looking up user records for 100 IDs.
# 20191014-155045: looking up user records for 100 IDs.
# 20191014-155046: looking up user records for 100 IDs.
# 20191014-155047: looking up user records for 100 IDs.
# 20191014-155048: looking up user records for 100 IDs.
# 20191014-155048: looking up user records for 100 IDs.
# 20191014-155049: looking up user records for 100 IDs.
# 20191014-155050: looking up user records for 100 IDs.
# 20191014-155051: looking up user records for 100 IDs.
# 20191014-155051: looking up user records for 100 IDs.
# 20191014-155052: looking up user records for 100 IDs.
# 20191014-155053: looking up user records for 100 IDs.
# 20191014-155054: looking up user records for 100 IDs.
# 20191014-155054: looking up user records for 100 IDs.
# 20191014-155055: looking up user records for 100 IDs.
# 20191014-155056: looking up user records for 100 IDs.
# 20191014-155057: looking up user records for 100 IDs.
# 20191014-155057: looking up user records for 100 IDs.
# 20191014-155058: looking up user records for 100 IDs.
# 20191014-155059: looking up user records for 100 IDs.
# 20191014-155059: looking up user records for 100 IDs.
# 20191014-155101: looking up user records for 100 IDs.
# 20191014-155101: looking up user records for 100 IDs.
# 20191014-155102: looking up user records for 100 IDs.
# 20191014-155103: looking up user records for 100 IDs.
# 20191014-155104: looking up user records for 100 IDs.
# 20191014-155104: looking up user records for 100 IDs.
# 20191014-155105: looking up user records for 100 IDs.
# 20191014-155106: looking up user records for 100 IDs.
# 20191014-155107: looking up user records for 100 IDs.
# 20191014-155107: looking up user records for 100 IDs.
# 20191014-155108: looking up user records for 100 IDs.
# 20191014-155109: looking up user records for 100 IDs.
# 20191014-155110: looking up user records for 100 IDs.
# 20191014-155110: looking up user records for 100 IDs.
# 20191014-155111: looking up user records for 100 IDs.
# 20191014-155112: looking up user records for 100 IDs.
# 20191014-155112: looking up user records for 100 IDs.
# 20191014-155113: looking up user records for 100 IDs.
# 20191014-155114: looking up user records for 100 IDs.
# 20191014-155115: looking up user records for 100 IDs.
# 20191014-155115: looking up user records for 100 IDs.
# 20191014-155116: looking up user records for 100 IDs.
# 20191014-155117: looking up user records for 100 IDs.
# 20191014-155117: looking up user records for 100 IDs.
# 20191014-155118: looking up user records for 100 IDs.
# 20191014-155119: looking up user records for 100 IDs.
# 20191014-155120: looking up user records for 100 IDs.
# 20191014-155120: looking up user records for 100 IDs.
# 20191014-155121: looking up user records for 100 IDs.
# 20191014-155122: looking up user records for 100 IDs.
# 20191014-155123: looking up user records for 100 IDs.
# 20191014-155123: looking up user records for 100 IDs.
# 20191014-155124: looking up user records for 100 IDs.
# 20191014-155125: looking up user records for 100 IDs.
# 20191014-155126: looking up user records for 100 IDs.
# 20191014-155127: looking up user records for 100 IDs.
# 20191014-155128: looking up user records for 100 IDs.
# 20191014-155128: looking up user records for 100 IDs.
# 20191014-155129: looking up user records for 100 IDs.
# 20191014-155130: looking up user records for 100 IDs.
# 20191014-155130: looking up user records for 100 IDs.
# 20191014-155131: looking up user records for 100 IDs.
# 20191014-155132: looking up user records for 100 IDs.
# 20191014-155133: looking up user records for 100 IDs.
# 20191014-155134: looking up user records for 100 IDs.
# 20191014-155134: looking up user records for 100 IDs.
# 20191014-155135: looking up user records for 100 IDs.
# 20191014-155136: looking up user records for 100 IDs.
# 20191014-155137: looking up user records for 100 IDs.
# 20191014-155137: looking up user records for 100 IDs.
# 20191014-155138: looking up user records for 100 IDs.
# 20191014-155139: looking up user records for 100 IDs.
# 20191014-155140: looking up user records for 100 IDs.
# 20191014-155140: looking up user records for 100 IDs.
# 20191014-155141: looking up user records for 100 IDs.
# 20191014-155142: looking up user records for 100 IDs.
# 20191014-155143: looking up user records for 100 IDs.
# 20191014-155143: looking up user records for 100 IDs.
# 20191014-155144: looking up user records for 100 IDs.
# 20191014-155145: looking up user records for 100 IDs.
# 20191014-155145: looking up user records for 100 IDs.
# 20191014-155146: looking up user records for 100 IDs.
# 20191014-155147: looking up user records for 100 IDs.
# 20191014-155148: looking up user records for 100 IDs.
# 20191014-155148: looking up user records for 100 IDs.
# 20191014-155149: looking up user records for 100 IDs.
# 20191014-155150: looking up user records for 100 IDs.
# 20191014-155151: looking up user records for 100 IDs.
# 20191014-155151: looking up user records for 100 IDs.
# 20191014-155152: looking up user records for 100 IDs.
# 20191014-155153: looking up user records for 100 IDs.
# 20191014-155154: looking up user records for 100 IDs.
# 20191014-155154: looking up user records for 100 IDs.
# 20191014-155155: looking up user records for 100 IDs.
# 20191014-155156: looking up user records for 100 IDs.
# 20191014-155157: looking up user records for 100 IDs.
# 20191014-155157: looking up user records for 100 IDs.
# 20191014-155158: looking up user records for 100 IDs.
# 20191014-155159: looking up user records for 100 IDs.
# 20191014-155200: looking up user records for 100 IDs.
# 20191014-155200: looking up user records for 100 IDs.
# 20191014-155201: looking up user records for 100 IDs.
# 20191014-155202: looking up user records for 100 IDs.
# 20191014-155203: looking up user records for 100 IDs.
# 20191014-155204: looking up user records for 100 IDs.
# 20191014-155204: looking up user records for 100 IDs.
# 20191014-155205: looking up user records for 100 IDs.
# 20191014-155206: looking up user records for 100 IDs.
# 20191014-155207: looking up user records for 100 IDs.
# 20191014-155207: looking up user records for 100 IDs.
# 20191014-155208: looking up user records for 100 IDs.
# 20191014-155209: looking up user records for 100 IDs.
# 20191014-155210: looking up user records for 100 IDs.
# 20191014-155210: looking up user records for 100 IDs.
# 20191014-155211: looking up user records for 100 IDs.
# 20191014-155212: looking up user records for 100 IDs.
# 20191014-155213: looking up user records for 100 IDs.
# 20191014-155213: looking up user records for 100 IDs.
# 20191014-155214: looking up user records for 100 IDs.
# 20191014-155215: looking up user records for 100 IDs.
# 20191014-155216: looking up user records for 100 IDs.
# 20191014-155216: looking up user records for 100 IDs.
# 20191014-155217: looking up user records for 100 IDs.
# 20191014-155218: looking up user records for 100 IDs.
# 20191014-155219: looking up user records for 100 IDs.
# 20191014-155219: looking up user records for 100 IDs.
# 20191014-155220: looking up user records for 100 IDs.
# 20191014-155221: looking up user records for 100 IDs.
# 20191014-155222: looking up user records for 100 IDs.
# 20191014-155223: looking up user records for 100 IDs.
# 20191014-155223: looking up user records for 100 IDs.
# 20191014-155224: looking up user records for 100 IDs.
# 20191014-155225: looking up user records for 100 IDs.
# 20191014-155226: looking up user records for 100 IDs.
# 20191014-155227: looking up user records for 100 IDs.
# 20191014-155227: looking up user records for 100 IDs.
# 20191014-155228: looking up user records for 100 IDs.
# 20191014-155229: looking up user records for 100 IDs.
# 20191014-155230: looking up user records for 100 IDs.
# 20191014-155231: looking up user records for 100 IDs.
# 20191014-155231: looking up user records for 100 IDs.
# 20191014-155232: looking up user records for 100 IDs.
# 20191014-155233: looking up user records for 100 IDs.
# 20191014-155234: looking up user records for 100 IDs.
# 20191014-155234: looking up user records for 100 IDs.
# 20191014-155235: looking up user records for 100 IDs.
# 20191014-155236: looking up user records for 100 IDs.
# 20191014-155237: looking up user records for 100 IDs.
# 20191014-155238: looking up user records for 100 IDs.
# 20191014-155239: looking up user records for 100 IDs.
# 20191014-155239: looking up user records for 100 IDs.
# 20191014-155240: looking up user records for 100 IDs.
# 20191014-155241: looking up user records for 100 IDs.
# 20191014-155242: looking up user records for 100 IDs.
# 20191014-155243: looking up user records for 100 IDs.
# 20191014-155243: looking up user records for 100 IDs.
# 20191014-155244: looking up user records for 100 IDs.
# 20191014-155245: looking up user records for 100 IDs.
# 20191014-155246: looking up user records for 100 IDs.
# 20191014-155246: looking up user records for 100 IDs.
# 20191014-155247: looking up user records for 100 IDs.
# 20191014-155248: looking up user records for 100 IDs.
# 20191014-155249: looking up user records for 100 IDs.
# 20191014-155249: looking up user records for 100 IDs.
# 20191014-155250: looking up user records for 100 IDs.
# 20191014-155251: looking up user records for 100 IDs.
# 20191014-155252: looking up user records for 100 IDs.
# 20191014-155252: looking up user records for 100 IDs.
# 20191014-155253: looking up user records for 100 IDs.
# 20191014-155254: looking up user records for 100 IDs.
# 20191014-155255: looking up user records for 100 IDs.
# 20191014-155255: looking up user records for 100 IDs.
# 20191014-155256: looking up user records for 100 IDs.
# 20191014-155257: looking up user records for 100 IDs.
# 20191014-155257: looking up user records for 100 IDs.
# 20191014-155258: looking up user records for 100 IDs.
# 20191014-155259: looking up user records for 100 IDs.
# 20191014-155300: looking up user records for 100 IDs.
# 20191014-155300: looking up user records for 100 IDs.
# 20191014-155302: looking up user records for 100 IDs.
# 20191014-155302: looking up user records for 100 IDs.
# 20191014-155303: looking up user records for 100 IDs.
# 20191014-155304: looking up user records for 100 IDs.
# 20191014-155305: looking up user records for 100 IDs.
# 20191014-155305: looking up user records for 100 IDs.
# 20191014-155306: looking up user records for 100 IDs.
# 20191014-155307: looking up user records for 100 IDs.
# 20191014-155308: looking up user records for 100 IDs.
# 20191014-155308: looking up user records for 100 IDs.
# 20191014-155309: looking up user records for 100 IDs.
# 20191014-155310: looking up user records for 100 IDs.
# 20191014-155311: looking up user records for 100 IDs.
# 20191014-155311: looking up user records for 100 IDs.
# 20191014-155312: looking up user records for 100 IDs.
# 20191014-155313: looking up user records for 100 IDs.
# 20191014-155314: looking up user records for 100 IDs.
# 20191014-155314: looking up user records for 100 IDs.
# 20191014-155315: looking up user records for 100 IDs.
# 20191014-155316: looking up user records for 100 IDs.
# 20191014-155317: looking up user records for 100 IDs.
# 20191014-155317: looking up user records for 100 IDs.
# 20191014-155318: looking up user records for 100 IDs.
# 20191014-155319: looking up user records for 100 IDs.
# 20191014-155320: looking up user records for 100 IDs.
# 20191014-155320: looking up user records for 100 IDs.
# 20191014-155321: looking up user records for 100 IDs.
# 20191014-155322: looking up user records for 100 IDs.
# 20191014-155322: looking up user records for 100 IDs.
# 20191014-155323: looking up user records for 100 IDs.
# 20191014-155324: looking up user records for 100 IDs.
# 20191014-155325: looking up user records for 100 IDs.
# 20191014-155325: looking up user records for 100 IDs.
# 20191014-155326: looking up user records for 100 IDs.
# 20191014-155327: looking up user records for 100 IDs.
# 20191014-155328: looking up user records for 100 IDs.
# 20191014-155329: looking up user records for 100 IDs.
# 20191014-155330: looking up user records for 100 IDs.
# 20191014-155330: looking up user records for 100 IDs.
# 20191014-155331: looking up user records for 100 IDs.
# 20191014-155332: looking up user records for 100 IDs.
# 20191014-155333: looking up user records for 100 IDs.
# 20191014-155333: looking up user records for 100 IDs.
# 20191014-155334: looking up user records for 100 IDs.
# 20191014-155335: looking up user records for 100 IDs.
# 20191014-155335: looking up user records for 100 IDs.
# 20191014-155336: looking up user records for 100 IDs.
# 20191014-155337: looking up user records for 100 IDs.
# 20191014-155338: looking up user records for 100 IDs.
# 20191014-155338: looking up user records for 100 IDs.
# 20191014-155339: looking up user records for 100 IDs.
# 20191014-155340: looking up user records for 100 IDs.
# 20191014-155341: looking up user records for 100 IDs.
# 20191014-155342: looking up user records for 100 IDs.
# 20191014-155342: looking up user records for 100 IDs.
# 20191014-155343: looking up user records for 100 IDs.
# 20191014-155344: looking up user records for 100 IDs.
# 20191014-155345: looking up user records for 100 IDs.
# 20191014-155345: looking up user records for 100 IDs.
# 20191014-155346: looking up user records for 100 IDs.
# 20191014-155347: looking up user records for 100 IDs.
# 20191014-155348: looking up user records for 100 IDs.
# 20191014-155348: looking up user records for 100 IDs.
# 20191014-155349: looking up user records for 100 IDs.
# 20191014-155350: looking up user records for 100 IDs.
# 20191014-155351: looking up user records for 100 IDs.
# 20191014-155351: looking up user records for 100 IDs.
# 20191014-155352: looking up user records for 100 IDs.
# 20191014-155353: looking up user records for 100 IDs.
# 20191014-155354: looking up user records for 100 IDs.
# 20191014-155355: looking up user records for 100 IDs.
# 20191014-155355: looking up user records for 100 IDs.
# 20191014-155356: looking up user records for 100 IDs.
# 20191014-155357: looking up user records for 100 IDs.
# 20191014-155358: looking up user records for 100 IDs.
# 20191014-155359: looking up user records for 100 IDs.
# 20191014-155359: looking up user records for 100 IDs.
# 20191014-155400: looking up user records for 100 IDs.
# 20191014-155401: looking up user records for 100 IDs.
# 20191014-155402: looking up user records for 100 IDs.
# 20191014-155402: looking up user records for 100 IDs.
# 20191014-155403: looking up user records for 100 IDs.
# 20191014-155404: looking up user records for 100 IDs.
# 20191014-155404: looking up user records for 100 IDs.
# 20191014-155405: looking up user records for 100 IDs.
# 20191014-155406: looking up user records for 100 IDs.
# 20191014-155407: looking up user records for 100 IDs.
# 20191014-155408: looking up user records for 100 IDs.
# 20191014-155408: looking up user records for 100 IDs.
# 20191014-155409: looking up user records for 100 IDs.
# 20191014-155410: looking up user records for 100 IDs.
# 20191014-155411: looking up user records for 100 IDs.
# 20191014-155411: looking up user records for 100 IDs.
# 20191014-155412: looking up user records for 100 IDs.
# 20191014-155413: looking up user records for 100 IDs.
# 20191014-155414: looking up user records for 100 IDs.
# 20191014-155415: looking up user records for 100 IDs.
# 20191014-155415: looking up user records for 100 IDs.
# 20191014-155416: looking up user records for 100 IDs.
# 20191014-155417: looking up user records for 100 IDs.
# 20191014-155418: looking up user records for 100 IDs.
# 20191014-155418: looking up user records for 100 IDs.
# 20191014-155419: looking up user records for 100 IDs.
# 20191014-155420: looking up user records for 100 IDs.
# 20191014-155421: looking up user records for 100 IDs.
# 20191014-155421: looking up user records for 100 IDs.
# 20191014-155422: looking up user records for 100 IDs.
# 20191014-155423: looking up user records for 100 IDs.
# 20191014-155424: looking up user records for 100 IDs.
# 20191014-155425: looking up user records for 100 IDs.
# 20191014-155425: looking up user records for 100 IDs.
# 20191014-155426: looking up user records for 100 IDs.
# 20191014-155427: looking up user records for 100 IDs.
# 20191014-155428: looking up user records for 100 IDs.
# 20191014-155428: looking up user records for 100 IDs.
# 20191014-155429: looking up user records for 100 IDs.
# 20191014-155430: looking up user records for 100 IDs.
# 20191014-155431: looking up user records for 100 IDs.
# 20191014-155431: looking up user records for 100 IDs.
# 20191014-155432: looking up user records for 100 IDs.
# 20191014-155433: looking up user records for 100 IDs.
# 20191014-155434: looking up user records for 100 IDs.
# 20191014-155434: looking up user records for 100 IDs.
# 20191014-155435: looking up user records for 100 IDs.
# 20191014-155436: looking up user records for 100 IDs.
# 20191014-155437: looking up user records for 100 IDs.
# 20191014-155437: looking up user records for 100 IDs.
# 20191014-155438: looking up user records for 100 IDs.
# 20191014-155439: looking up user records for 100 IDs.
# 20191014-155440: looking up user records for 100 IDs.
# 20191014-155440: looking up user records for 100 IDs.
# 20191014-155441: looking up user records for 100 IDs.
# 20191014-155442: looking up user records for 100 IDs.
# 20191014-155443: looking up user records for 100 IDs.
# 20191014-155443: looking up user records for 100 IDs.
# 20191014-155444: looking up user records for 100 IDs.
# 20191014-155445: looking up user records for 100 IDs.
# 20191014-155446: looking up user records for 100 IDs.
# 20191014-155447: looking up user records for 100 IDs.
# 20191014-155447: looking up user records for 100 IDs.
# 20191014-155448: looking up user records for 100 IDs.
# 20191014-155449: looking up user records for 100 IDs.
# 20191014-155450: looking up user records for 100 IDs.
# 20191014-155451: looking up user records for 100 IDs.
# 20191014-155451: looking up user records for 100 IDs.
# 20191014-155452: looking up user records for 100 IDs.
# 20191014-155453: looking up user records for 100 IDs.
# 20191014-155454: looking up user records for 100 IDs.
# 20191014-155454: looking up user records for 100 IDs.
# 20191014-155455: looking up user records for 100 IDs.
# 20191014-155456: looking up user records for 100 IDs.
# 20191014-155457: looking up user records for 100 IDs.
# 20191014-155457: looking up user records for 100 IDs.
# 20191014-155458: looking up user records for 100 IDs.
# 20191014-155459: looking up user records for 100 IDs.
# 20191014-155500: looking up user records for 100 IDs.
# 20191014-155501: looking up user records for 100 IDs.
# 20191014-155501: looking up user records for 100 IDs.
# 20191014-155502: looking up user records for 100 IDs.
# 20191014-155503: looking up user records for 100 IDs.
# 20191014-155504: looking up user records for 100 IDs.
# 20191014-155505: looking up user records for 100 IDs.
# 20191014-155505: looking up user records for 100 IDs.
# 20191014-155506: looking up user records for 100 IDs.
# 20191014-155507: looking up user records for 100 IDs.
# 20191014-155508: looking up user records for 100 IDs.
# 20191014-155509: looking up user records for 100 IDs.
# 20191014-155509: looking up user records for 100 IDs.
# 20191014-155510: looking up user records for 100 IDs.
# 20191014-155511: looking up user records for 100 IDs.
# 20191014-155512: looking up user records for 100 IDs.
# 20191014-155513: looking up user records for 100 IDs.
# 20191014-155513: looking up user records for 100 IDs.
# 20191014-155514: looking up user records for 100 IDs.
# 20191014-155515: looking up user records for 100 IDs.
# 20191014-155516: looking up user records for 100 IDs.
# 20191014-155516: looking up user records for 100 IDs.
# 20191014-155517: looking up user records for 100 IDs.
# 20191014-155518: looking up user records for 100 IDs.
# 20191014-155519: looking up user records for 100 IDs.
# 20191014-155519: looking up user records for 100 IDs.
# 20191014-155520: looking up user records for 100 IDs.
# 20191014-155521: looking up user records for 100 IDs.
# 20191014-155521: looking up user records for 100 IDs.
# 20191014-155522: looking up user records for 100 IDs.
# 20191014-155523: looking up user records for 100 IDs.
# 20191014-155524: looking up user records for 100 IDs.
# 20191014-155525: looking up user records for 100 IDs.
# 20191014-155526: looking up user records for 100 IDs.
# 20191014-155526: looking up user records for 100 IDs.
# 20191014-155527: looking up user records for 100 IDs.
# 20191014-155528: looking up user records for 100 IDs.
# 20191014-155528: looking up user records for 100 IDs.
# 20191014-155529: looking up user records for 100 IDs.
# 20191014-155530: looking up user records for 100 IDs.
# 20191014-155531: looking up user records for 100 IDs.
# 20191014-155531: looking up user records for 100 IDs.
# 20191014-155532: looking up user records for 100 IDs.
# 20191014-155533: looking up user records for 100 IDs.
# 20191014-155534: looking up user records for 100 IDs.
# 20191014-155535: looking up user records for 100 IDs.
# 20191014-155535: looking up user records for 100 IDs.
# 20191014-155536: looking up user records for 100 IDs.
# 20191014-155537: looking up user records for 100 IDs.
# 20191014-155538: looking up user records for 100 IDs.
# 20191014-155538: looking up user records for 100 IDs.
# 20191014-155539: looking up user records for 100 IDs.
# 20191014-155540: looking up user records for 100 IDs.
# 20191014-155541: looking up user records for 100 IDs.
# 20191014-155541: looking up user records for 100 IDs.
# 20191014-155542: looking up user records for 100 IDs.
# 20191014-155543: looking up user records for 100 IDs.
# 20191014-155544: looking up user records for 100 IDs.
# 20191014-155544: looking up user records for 100 IDs.
# 20191014-155545: looking up user records for 100 IDs.
# 20191014-155546: looking up user records for 100 IDs.
# 20191014-155547: looking up user records for 100 IDs.
# 20191014-155547: looking up user records for 100 IDs.
# 20191014-155548: looking up user records for 100 IDs.
# 20191014-155549: looking up user records for 100 IDs.
# 20191014-155550: looking up user records for 100 IDs.
# 20191014-155550: looking up user records for 100 IDs.
# 20191014-155551: looking up user records for 100 IDs.
# 20191014-155552: looking up user records for 100 IDs.
# 20191014-155553: looking up user records for 100 IDs.
# 20191014-155553: looking up user records for 100 IDs.
# 20191014-155554: looking up user records for 100 IDs.
# 20191014-155555: looking up user records for 100 IDs.
# 20191014-155556: looking up user records for 100 IDs.
# 20191014-155556: looking up user records for 100 IDs.
# 20191014-155557: looking up user records for 100 IDs.
# 20191014-155558: looking up user records for 100 IDs.
# 20191014-155559: looking up user records for 100 IDs.
# 20191014-155559: looking up user records for 100 IDs.
# 20191014-155600: looking up user records for 100 IDs.
# 20191014-155601: looking up user records for 100 IDs.
# 20191014-155602: looking up user records for 100 IDs.
# 20191014-155602: looking up user records for 100 IDs.
# 20191014-155603: looking up user records for 100 IDs.
# 20191014-155604: looking up user records for 100 IDs.
# 20191014-155605: looking up user records for 100 IDs.
# 20191014-155606: looking up user records for 100 IDs.
# 20191014-155606: looking up user records for 100 IDs.
# 20191014-155607: looking up user records for 100 IDs.
# 20191014-155608: looking up user records for 100 IDs.
# 20191014-155609: looking up user records for 100 IDs.
# 20191014-155610: looking up user records for 100 IDs.
# 20191014-155610: looking up user records for 100 IDs.
# 20191014-155611: looking up user records for 100 IDs.
# 20191014-155612: looking up user records for 100 IDs.
# 20191014-155613: looking up user records for 100 IDs.
# 20191014-155614: looking up user records for 100 IDs.
# 20191014-155614: looking up user records for 100 IDs.
# 20191014-155615: looking up user records for 100 IDs.
# 20191014-155616: looking up user records for 100 IDs.
# 20191014-155617: looking up user records for 100 IDs.
# 20191014-155618: looking up user records for 100 IDs.
# 20191014-155619: looking up user records for 100 IDs.
# 20191014-155619: looking up user records for 100 IDs.
# 20191014-155620: looking up user records for 100 IDs.
# 20191014-155621: looking up user records for 100 IDs.
# 20191014-155622: looking up user records for 100 IDs.
# 20191014-155622: looking up user records for 100 IDs.
# 20191014-155623: looking up user records for 100 IDs.
# 20191014-155624: looking up user records for 100 IDs.
# 20191014-155625: looking up user records for 100 IDs.
# 20191014-155626: looking up user records for 100 IDs.
# 20191014-155626: looking up user records for 100 IDs.
# 20191014-155627: looking up user records for 100 IDs.
# 20191014-155628: looking up user records for 100 IDs.
# 20191014-155629: looking up user records for 100 IDs.
# 20191014-155629: looking up user records for 100 IDs.
# 20191014-155630: looking up user records for 100 IDs.
# 20191014-155631: looking up user records for 100 IDs.
# 20191014-155632: looking up user records for 100 IDs.
# 20191014-155632: looking up user records for 100 IDs.
# 20191014-155634: looking up user records for 100 IDs.
# 20191014-155634: looking up user records for 100 IDs.
# 20191014-155635: looking up user records for 100 IDs.
# 20191014-155636: looking up user records for 100 IDs.
# 20191014-155637: looking up user records for 100 IDs.
# 20191014-155637: looking up user records for 100 IDs.
# 20191014-155638: looking up user records for 100 IDs.
# 20191014-155639: looking up user records for 100 IDs.
# 20191014-155640: looking up user records for 100 IDs.
# 20191014-155640: looking up user records for 100 IDs.
# 20191014-155641: looking up user records for 100 IDs.
# 20191014-155642: looking up user records for 100 IDs.
# 20191014-155643: looking up user records for 100 IDs.
# 20191014-155643: looking up user records for 100 IDs.
# 20191014-155644: looking up user records for 100 IDs.
# 20191014-155645: looking up user records for 100 IDs.
# 20191014-155646: looking up user records for 100 IDs.
# 20191014-155647: looking up user records for 100 IDs.
# 20191014-155647: looking up user records for 100 IDs.
# 20191014-155648: looking up user records for 100 IDs.
# 20191014-155649: looking up user records for 100 IDs.
# 20191014-155650: looking up user records for 100 IDs.
# 20191014-155650: looking up user records for 100 IDs.
# 20191014-155651: looking up user records for 100 IDs.
# 20191014-155652: looking up user records for 100 IDs.
# 20191014-155653: looking up user records for 100 IDs.
# 20191014-155653: looking up user records for 100 IDs.
# 20191014-155654: looking up user records for 100 IDs.
# 20191014-155655: looking up user records for 100 IDs.
# 20191014-155656: looking up user records for 100 IDs.
# 20191014-155656: looking up user records for 100 IDs.
# 20191014-155657: looking up user records for 100 IDs.
# 20191014-155658: looking up user records for 100 IDs.
# 20191014-155659: looking up user records for 100 IDs.
# 20191014-155700: looking up user records for 100 IDs.
# 20191014-155701: looking up user records for 100 IDs.
# 20191014-155701: looking up user records for 100 IDs.
# 20191014-155703: looking up user records for 100 IDs.
# 20191014-155703: looking up user records for 100 IDs.
# 20191014-155704: looking up user records for 100 IDs.
# 20191014-155705: looking up user records for 100 IDs.
# 20191014-155705: looking up user records for 100 IDs.
# 20191014-155706: looking up user records for 100 IDs.
# 20191014-155707: looking up user records for 100 IDs.
# 20191014-155708: looking up user records for 100 IDs.
# 20191014-155708: looking up user records for 100 IDs.
# 20191014-155709: looking up user records for 100 IDs.
# 20191014-155710: looking up user records for 100 IDs.
# 20191014-155711: looking up user records for 100 IDs.
# 20191014-155712: looking up user records for 100 IDs.
# 20191014-155712: looking up user records for 100 IDs.
# 20191014-155713: looking up user records for 100 IDs.
# 20191014-155714: looking up user records for 100 IDs.
# 20191014-155714: looking up user records for 100 IDs.
# 20191014-155715: looking up user records for 100 IDs.
# 20191014-155716: looking up user records for 100 IDs.
# 20191014-155717: looking up user records for 100 IDs.
# 20191014-155718: looking up user records for 100 IDs.
# 20191014-155719: looking up user records for 100 IDs.
# 20191014-155720: looking up user records for 100 IDs.
# 20191014-155721: looking up user records for 100 IDs.
# 20191014-155721: looking up user records for 100 IDs.
# 20191014-155722: looking up user records for 100 IDs.
# 20191014-155723: looking up user records for 100 IDs.
# 20191014-155724: looking up user records for 100 IDs.
# 20191014-155724: looking up user records for 100 IDs.
# 20191014-155725: looking up user records for 100 IDs.
# 20191014-155726: looking up user records for 100 IDs.
# 20191014-155727: looking up user records for 100 IDs.
# 20191014-155727: looking up user records for 100 IDs.
# 20191014-155728: looking up user records for 100 IDs.
# 20191014-155729: looking up user records for 100 IDs.
# 20191014-155730: looking up user records for 100 IDs.
# 20191014-155730: looking up user records for 100 IDs.
# 20191014-155731: looking up user records for 100 IDs.
# 20191014-155732: looking up user records for 100 IDs.
# 20191014-155733: looking up user records for 100 IDs.
# 20191014-155733: looking up user records for 100 IDs.
# 20191014-155734: looking up user records for 100 IDs.
# 20191014-155735: looking up user records for 100 IDs.
# 20191014-155736: looking up user records for 100 IDs.
# 20191014-155736: looking up user records for 100 IDs.
# 20191014-155737: looking up user records for 100 IDs.
# 20191014-155738: looking up user records for 100 IDs.
# 20191014-155739: looking up user records for 100 IDs.
# 20191014-155739: looking up user records for 100 IDs.
# 20191014-155740: looking up user records for 100 IDs.
# 20191014-155741: looking up user records for 100 IDs.
# 20191014-155741: looking up user records for 100 IDs.
# 20191014-155742: looking up user records for 100 IDs.
# 20191014-155743: looking up user records for 100 IDs.
# 20191014-155744: looking up user records for 100 IDs.
# 20191014-155744: looking up user records for 100 IDs.
# 20191014-155745: looking up user records for 100 IDs.
# 20191014-155746: looking up user records for 100 IDs.
# 20191014-155747: looking up user records for 100 IDs.
# 20191014-155747: looking up user records for 100 IDs.
# 20191014-155748: looking up user records for 100 IDs.
# 20191014-155749: looking up user records for 100 IDs.
# 20191014-155750: looking up user records for 100 IDs.
# 20191014-155750: looking up user records for 100 IDs.
# 20191014-155751: looking up user records for 100 IDs.
# 20191014-155752: looking up user records for 100 IDs.
# 20191014-155753: looking up user records for 100 IDs.
# 20191014-155754: looking up user records for 100 IDs.
# 20191014-155754: looking up user records for 100 IDs.
# 20191014-155755: looking up user records for 100 IDs.
# 20191014-155756: looking up user records for 100 IDs.
# 20191014-155757: looking up user records for 100 IDs.
# 20191014-155758: looking up user records for 100 IDs.
# 20191014-155758: looking up user records for 100 IDs.
# 20191014-155759: looking up user records for 100 IDs.
# 20191014-155800: looking up user records for 100 IDs.
# 20191014-155801: looking up user records for 100 IDs.
# 20191014-155801: looking up user records for 100 IDs.
# 20191014-155802: looking up user records for 100 IDs.
# 20191014-155803: looking up user records for 100 IDs.
# 20191014-155804: looking up user records for 100 IDs.
# 20191014-155805: looking up user records for 100 IDs.
# 20191014-155805: looking up user records for 100 IDs.
# 20191014-155806: looking up user records for 100 IDs.
# 20191014-155807: looking up user records for 100 IDs.
# 20191014-155808: looking up user records for 100 IDs.
# 20191014-155808: looking up user records for 100 IDs.
# 20191014-155809: looking up user records for 100 IDs.
# 20191014-155810: looking up user records for 100 IDs.
# 20191014-155811: looking up user records for 100 IDs.
# 20191014-155812: looking up user records for 100 IDs.
# 20191014-155812: looking up user records for 100 IDs.
# 20191014-155813: looking up user records for 100 IDs.
# 20191014-155814: looking up user records for 100 IDs.
# 20191014-155815: looking up user records for 100 IDs.
# 20191014-155815: looking up user records for 100 IDs.
# 20191014-155816: looking up user records for 100 IDs.
# 20191014-155817: looking up user records for 100 IDs.
# 20191014-155817: looking up user records for 100 IDs.
# 20191014-155818: looking up user records for 100 IDs.
# 20191014-155819: looking up user records for 100 IDs.
# 20191014-155820: looking up user records for 100 IDs.
# 20191014-155820: looking up user records for 100 IDs.
# 20191014-155821: looking up user records for 100 IDs.
# 20191014-155822: looking up user records for 100 IDs.
# 20191014-155822: looking up user records for 100 IDs.
# 20191014-155823: looking up user records for 100 IDs.
# 20191014-155824: looking up user records for 100 IDs.
# 20191014-155825: looking up user records for 100 IDs.
# 20191014-155825: looking up user records for 100 IDs.
# 20191014-155826: looking up user records for 100 IDs.
# 20191014-155827: looking up user records for 100 IDs.
# 20191014-155827: looking up user records for 100 IDs.
# 20191014-155828: looking up user records for 100 IDs.
# 20191014-155829: looking up user records for 100 IDs.
# 20191014-155830: looking up user records for 100 IDs.
# 20191014-155831: looking up user records for 100 IDs.
# 20191014-155832: looking up user records for 100 IDs.
# 20191014-155833: looking up user records for 100 IDs.
# 20191014-155833: looking up user records for 100 IDs.
# 20191014-155834: looking up user records for 100 IDs.
# 20191014-155835: looking up user records for 100 IDs.
# 20191014-155836: looking up user records for 100 IDs.
# 20191014-155836: looking up user records for 100 IDs.
# 20191014-155837: looking up user records for 100 IDs.
# 20191014-155838: looking up user records for 100 IDs.
# 20191014-155839: looking up user records for 100 IDs.
# 20191014-155839: looking up user records for 100 IDs.
# 20191014-155840: looking up user records for 100 IDs.
# 20191014-155841: looking up user records for 100 IDs.
# 20191014-155842: looking up user records for 100 IDs.
# 20191014-155842: looking up user records for 100 IDs.
# 20191014-155843: looking up user records for 100 IDs.
# 20191014-155844: looking up user records for 100 IDs.
# 20191014-155845: looking up user records for 100 IDs.
# 20191014-155846: looking up user records for 100 IDs.
# 20191014-155846: looking up user records for 100 IDs.
# 20191014-155847: looking up user records for 100 IDs.
# 20191014-155848: looking up user records for 100 IDs.
# 20191014-155849: looking up user records for 100 IDs.
# 20191014-155850: looking up user records for 100 IDs.
# 20191014-155850: looking up user records for 100 IDs.
# 20191014-155851: looking up user records for 100 IDs.
# 20191014-155852: looking up user records for 100 IDs.
# 20191014-155852: looking up user records for 100 IDs.
# 20191014-155853: looking up user records for 100 IDs.
# 20191014-155854: looking up user records for 100 IDs.
# 20191014-155855: looking up user records for 100 IDs.
# 20191014-155856: looking up user records for 100 IDs.
# 20191014-155857: looking up user records for 100 IDs.
# 20191014-155857: looking up user records for 100 IDs.
# 20191014-155858: looking up user records for 100 IDs.
# 20191014-155859: looking up user records for 100 IDs.
# 20191014-155900: looking up user records for 100 IDs.
# 20191014-155901: looking up user records for 100 IDs.
# 20191014-155902: looking up user records for 100 IDs.
# 20191014-155903: looking up user records for 100 IDs.
# 20191014-155904: looking up user records for 100 IDs.
# 20191014-155904: looking up user records for 100 IDs.
# 20191014-155905: looking up user records for 100 IDs.
# 20191014-155906: looking up user records for 100 IDs.
# 20191014-155907: looking up user records for 100 IDs.
# 20191014-155908: looking up user records for 100 IDs.
# 20191014-155908: looking up user records for 100 IDs.
# 20191014-155909: looking up user records for 100 IDs.
# 20191014-155910: looking up user records for 100 IDs.
# 20191014-155911: looking up user records for 100 IDs.
# 20191014-155911: looking up user records for 100 IDs.
# 20191014-155912: looking up user records for 100 IDs.
# 20191014-155913: looking up user records for 100 IDs.
# 20191014-155913: looking up user records for 100 IDs.
# 20191014-155914: looking up user records for 100 IDs.
# 20191014-155915: looking up user records for 100 IDs.
# 20191014-155916: looking up user records for 100 IDs.
# 20191014-155916: looking up user records for 100 IDs.
# 20191014-155917: looking up user records for 100 IDs.
# 20191014-155918: looking up user records for 100 IDs.
# 20191014-155919: looking up user records for 100 IDs.
# 20191014-155919: looking up user records for 100 IDs.
# 20191014-155920: looking up user records for 100 IDs.
# 20191014-155921: looking up user records for 100 IDs.
# 20191014-155922: looking up user records for 100 IDs.
# 20191014-155922: looking up user records for 100 IDs.
# 20191014-155923: looking up user records for 100 IDs.
# 20191014-155924: looking up user records for 100 IDs.
# 20191014-155925: looking up user records for 100 IDs.
# 20191014-155925: looking up user records for 100 IDs.
# 20191014-155926: looking up user records for 100 IDs.
# 20191014-155927: looking up user records for 100 IDs.
# 20191014-155928: looking up user records for 100 IDs.
# 20191014-155928: looking up user records for 100 IDs.
# 20191014-155929: looking up user records for 100 IDs.
# 20191014-155930: looking up user records for 100 IDs.
# 20191014-155931: looking up user records for 100 IDs.
# 20191014-155932: looking up user records for 100 IDs.
# 20191014-155932: looking up user records for 100 IDs.
# 20191014-155933: looking up user records for 100 IDs.
# 20191014-155934: looking up user records for 100 IDs.
# 20191014-155934: looking up user records for 100 IDs.
# 20191014-155935: looking up user records for 100 IDs.
# 20191014-155936: looking up user records for 100 IDs.
# 20191014-155937: looking up user records for 100 IDs.
# 20191014-155937: looking up user records for 100 IDs.
# 20191014-155938: looking up user records for 100 IDs.
# 20191014-155939: looking up user records for 100 IDs.
# 20191014-155940: looking up user records for 100 IDs.
# 20191014-155940: looking up user records for 100 IDs.
# 20191014-155941: looking up user records for 100 IDs.
# 20191014-155942: looking up user records for 100 IDs.
# 20191014-155943: looking up user records for 100 IDs.
# 20191014-155944: looking up user records for 100 IDs.
# 20191014-155944: looking up user records for 100 IDs.
# 20191014-155945: looking up user records for 100 IDs.
# 20191014-155946: looking up user records for 100 IDs.
# 20191014-155947: looking up user records for 100 IDs.
# 20191014-155947: looking up user records for 100 IDs.
# 20191014-155948: looking up user records for 100 IDs.
# 20191014-155949: looking up user records for 100 IDs.
# 20191014-155950: looking up user records for 100 IDs.
# 20191014-155951: looking up user records for 100 IDs.
# 20191014-155951: looking up user records for 100 IDs.
# 20191014-155952: looking up user records for 100 IDs.
# 20191014-155953: looking up user records for 100 IDs.
# 20191014-155954: looking up user records for 100 IDs.
# 20191014-155954: looking up user records for 100 IDs.
# 20191014-155955: looking up user records for 100 IDs.
# 20191014-155956: looking up user records for 100 IDs.
# 20191014-155956: looking up user records for 100 IDs.
# 20191014-155957: looking up user records for 100 IDs.
# 20191014-155958: looking up user records for 100 IDs.
# 20191014-155959: looking up user records for 100 IDs.
# 20191014-155959: looking up user records for 100 IDs.
# 20191014-160000: looking up user records for 100 IDs.
# 20191014-160001: looking up user records for 100 IDs.
# 20191014-160002: looking up user records for 100 IDs.
# 20191014-160003: looking up user records for 100 IDs.
# 20191014-160004: looking up user records for 100 IDs.
# 20191014-160005: looking up user records for 100 IDs.
# 20191014-160006: looking up user records for 100 IDs.
# 20191014-160007: looking up user records for 100 IDs.
# 20191014-160007: looking up user records for 100 IDs.
# 20191014-160008: looking up user records for 100 IDs.
# 20191014-160009: looking up user records for 100 IDs.
# 20191014-160010: looking up user records for 100 IDs.
# 20191014-160010: looking up user records for 100 IDs.
# 20191014-160011: looking up user records for 100 IDs.
# 20191014-160012: looking up user records for 100 IDs.
# 20191014-160013: looking up user records for 100 IDs.
# 20191014-160013: looking up user records for 100 IDs.
# 20191014-160014: looking up user records for 100 IDs.
# 20191014-160015: looking up user records for 100 IDs.
# 20191014-160016: looking up user records for 100 IDs.
# 20191014-160016: looking up user records for 100 IDs.
# 20191014-160017: looking up user records for 100 IDs.
# 20191014-160018: looking up user records for 100 IDs.
# 20191014-160019: looking up user records for 100 IDs.
# 20191014-160020: looking up user records for 100 IDs.
# 20191014-160020: looking up user records for 100 IDs.
# 20191014-160021: looking up user records for 100 IDs.
# 20191014-160022: looking up user records for 100 IDs.
# 20191014-160023: looking up user records for 100 IDs.
# 20191014-160023: looking up user records for 100 IDs.
# 20191014-160024: looking up user records for 100 IDs.
# 20191014-160025: looking up user records for 100 IDs.
# 20191014-160026: looking up user records for 100 IDs.
# 20191014-160027: looking up user records for 100 IDs.
# 20191014-160027: looking up user records for 100 IDs.
# 20191014-160028: looking up user records for 100 IDs.
# 20191014-160029: looking up user records for 100 IDs.
# 20191014-160030: looking up user records for 100 IDs.
# 20191014-160030: looking up user records for 100 IDs.
# 20191014-160031: looking up user records for 100 IDs.
# 20191014-160032: looking up user records for 100 IDs.
# 20191014-160033: looking up user records for 100 IDs.
# 20191014-160034: looking up user records for 100 IDs.
# 20191014-160034: looking up user records for 100 IDs.
# 20191014-160035: looking up user records for 100 IDs.
# 20191014-160036: looking up user records for 100 IDs.
# 20191014-160037: looking up user records for 100 IDs.
# 20191014-160037: looking up user records for 100 IDs.
# 20191014-160038: looking up user records for 100 IDs.
# 20191014-160039: looking up user records for 100 IDs.
# 20191014-160040: looking up user records for 100 IDs.
# 20191014-160041: looking up user records for 100 IDs.
# 20191014-160041: looking up user records for 100 IDs.
# 20191014-160042: looking up user records for 100 IDs.
# 20191014-160043: looking up user records for 100 IDs.
# 20191014-160044: looking up user records for 100 IDs.
# 20191014-160045: looking up user records for 100 IDs.
# 20191014-160046: looking up user records for 100 IDs.
# Rate limit reached. Sleeping for: 209
# 20191014-160046: looking up user records for 100 IDs.
# 20191014-160421: looking up user records for 100 IDs.
# 20191014-160422: looking up user records for 100 IDs.
# 20191014-160423: looking up user records for 100 IDs.
# 20191014-160424: looking up user records for 100 IDs.
# 20191014-160424: looking up user records for 100 IDs.
# 20191014-160425: looking up user records for 100 IDs.
# 20191014-160426: looking up user records for 100 IDs.
# 20191014-160427: looking up user records for 100 IDs.
# 20191014-160428: looking up user records for 100 IDs.
# 20191014-160428: looking up user records for 100 IDs.
# 20191014-160429: looking up user records for 100 IDs.
# 20191014-160430: looking up user records for 100 IDs.
# 20191014-160431: looking up user records for 100 IDs.
# 20191014-160432: looking up user records for 100 IDs.
# 20191014-160433: looking up user records for 100 IDs.
# 20191014-160433: looking up user records for 100 IDs.
# 20191014-160434: looking up user records for 100 IDs.
# 20191014-160435: looking up user records for 100 IDs.
# 20191014-160436: looking up user records for 100 IDs.
# 20191014-160436: looking up user records for 100 IDs.
# 20191014-160437: looking up user records for 100 IDs.
# 20191014-160438: looking up user records for 100 IDs.
# 20191014-160439: looking up user records for 100 IDs.
# 20191014-160440: looking up user records for 100 IDs.
# 20191014-160440: looking up user records for 100 IDs.
# 20191014-160441: looking up user records for 100 IDs.
# 20191014-160442: looking up user records for 100 IDs.
# 20191014-160442: looking up user records for 100 IDs.
# 20191014-160443: looking up user records for 100 IDs.
# 20191014-160444: looking up user records for 100 IDs.
# 20191014-160445: looking up user records for 100 IDs.
# 20191014-160446: looking up user records for 100 IDs.
# 20191014-160446: looking up user records for 100 IDs.
# 20191014-160447: looking up user records for 100 IDs.
# 20191014-160448: looking up user records for 100 IDs.
# 20191014-160449: looking up user records for 100 IDs.
# 20191014-160449: looking up user records for 100 IDs.
# 20191014-160450: looking up user records for 100 IDs.
# 20191014-160451: looking up user records for 100 IDs.
# 20191014-160452: looking up user records for 100 IDs.
# 20191014-160453: looking up user records for 100 IDs.
# 20191014-160454: looking up user records for 100 IDs.
# 20191014-160454: looking up user records for 100 IDs.
# 20191014-160455: looking up user records for 100 IDs.
# 20191014-160456: looking up user records for 100 IDs.
# 20191014-160457: looking up user records for 100 IDs.
# 20191014-160457: looking up user records for 100 IDs.
# 20191014-160458: looking up user records for 100 IDs.
# 20191014-160459: looking up user records for 100 IDs.
# 20191014-160459: looking up user records for 100 IDs.
# 20191014-160500: looking up user records for 100 IDs.
# 20191014-160501: looking up user records for 100 IDs.
# 20191014-160502: looking up user records for 100 IDs.
# 20191014-160502: looking up user records for 100 IDs.
# 20191014-160503: looking up user records for 100 IDs.
# 20191014-160504: looking up user records for 100 IDs.
# 20191014-160505: looking up user records for 100 IDs.
# 20191014-160505: looking up user records for 100 IDs.
# 20191014-160506: looking up user records for 100 IDs.
# 20191014-160507: looking up user records for 100 IDs.
# 20191014-160508: looking up user records for 100 IDs.
# 20191014-160508: looking up user records for 100 IDs.
# 20191014-160509: looking up user records for 100 IDs.
# 20191014-160510: looking up user records for 100 IDs.
# 20191014-160511: looking up user records for 100 IDs.
# 20191014-160511: looking up user records for 100 IDs.
# 20191014-160512: looking up user records for 100 IDs.
# 20191014-160513: looking up user records for 100 IDs.
# 20191014-160514: looking up user records for 100 IDs.
# 20191014-160514:  users pulled:  97000
# total failures: 0
# Start lookup_users_from_ids on 3054 IDs.
# 20191014-160514: looking up user records for 100 IDs.
# 20191014-160515: looking up user records for 100 IDs.
# 20191014-160516: looking up user records for 100 IDs.
# 20191014-160516: looking up user records for 100 IDs.
# 20191014-160517: looking up user records for 100 IDs.
# 20191014-160518: looking up user records for 100 IDs.
# 20191014-160519: looking up user records for 100 IDs.
# 20191014-160519: looking up user records for 100 IDs.
# 20191014-160520: looking up user records for 100 IDs.
# 20191014-160521: looking up user records for 100 IDs.
# 20191014-160522: looking up user records for 100 IDs.
# 20191014-160523: looking up user records for 100 IDs.
# 20191014-160523: looking up user records for 100 IDs.
# 20191014-160524: looking up user records for 100 IDs.
# 20191014-160525: looking up user records for 100 IDs.
# 20191014-160526: looking up user records for 100 IDs.
# 20191014-160527: looking up user records for 100 IDs.
# 20191014-160527: looking up user records for 100 IDs.
# 20191014-160528: looking up user records for 100 IDs.
# 20191014-160529: looking up user records for 100 IDs.
# 20191014-160529: looking up user records for 100 IDs.
# 20191014-160530: looking up user records for 100 IDs.
# 20191014-160531: looking up user records for 100 IDs.
# 20191014-160532: looking up user records for 100 IDs.
# 20191014-160532: looking up user records for 100 IDs.
# 20191014-160533: looking up user records for 100 IDs.
# 20191014-160534: looking up user records for 100 IDs.
# 20191014-160534: looking up user records for 100 IDs.
# 20191014-160535: looking up user records for 100 IDs.
# 20191014-160536: looking up user records for 100 IDs.
# 20191014-160537: looking up user records for 54 IDs.
# 20191014-160537:  users pulled:  3054
# total failures: 0

# %%
# Now let's write out all the records. I wrote some functions to help.
with open(ofile_name,'w') as ofile :
    write_user_rec_headers(ofile)
    for id, rec in all_records.items() :
        write_user_rec(ofile, rec)
